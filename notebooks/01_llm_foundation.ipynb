# %%
import requests
import json

# %%
OLLAMA_URL = "http://localhost:11434/api/generate"

payload = {
    "model": "llama3",
    "prompt": "Explain what budgeting means in one sentence.",
    "stream": False
}

response = requests.post(OLLAMA_URL, json=payload)

print (response.json()["response"])
# Out:
# Budgeting is the process of planning and managing one's financial resources by assigning specific amounts of money to different categories, such as income, expenses, savings, and debt repayment, to achieve short-term and long-term financial goals.
