# %%
import sys
sys.path.append("..")

from src.agents.intent_agent import IntentAgent
from src.agents.policy_agent import PolicyAgent
from src.agents.response_agent import ResponseAgent

intent_agent = IntentAgent()
policy_agent = PolicyAgent()
response_agent = ResponseAgent()

# Test allowed query
user_input = "How can I save money every month?"

intent_output = intent_agent.run(user_input)
policy_output = policy_agent.run(intent_output)
final_response = response_agent.run(policy_output)

print("Intent:", intent_output)
print("Policy:", policy_output)
print("Response:", final_response)
# Out:
# Intent: {'intent': 'budgeting', 'original_query': 'How can I save money every month?'}
# Policy: {'allowed': True, 'intent_data': {'intent': 'budgeting', 'original_query': 'How can I save money every month?'}}
# Response: Saving money is an essential part of achieving your long-term financial goals. Here are some practical tips to help you get started:
#
# 1. **Set a goal**: Define what you want to save for, whether it's a short-term goal like a vacation or a long-term goal like retirement. This will help you stay motivated to stick to your savings plan.
# 2. **Create a budget**: Track your income and expenses to understand where your money is going. Make a budget that accounts for all your necessary expenses, and then identify areas where you can cut back to free up more money for saving.
# ...
