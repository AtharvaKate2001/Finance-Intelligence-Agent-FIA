# %%
import sys
sys.path.append("..")

from src.agents.intent_agent import IntentAgent
from src.agents.policy_agent import PolicyAgent
from src.agents.response_agent import ResponseAgent
from src.agents.retrieval_agent import RetrievalAgent

# Agents
intent_agent = IntentAgent()
policy_agent = PolicyAgent()
retrieval_agent = RetrievalAgent(embedder, vector_store)
response_agent = ResponseAgent()

# Test query
user_input = "How much should I keep in an emergency fund?"

intent_output = intent_agent.run(user_input)
policy_output = policy_agent.run(intent_output)

retrieved_chunks = retrieval_agent.run(user_input)

final_response = response_agent.run(policy_output, retrieved_chunks)

print(final_response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 12
#      10 intent_agent = IntentAgent()
#      11 policy_agent = PolicyAgent()
# ---> 12 retrieval_agent = RetrievalAgent(embedder, vector_store)
#      13 response_agent = ResponseAgent()
#      15 # Test query
#
# NameError: name 'embedder' is not defined

# %%
import sys
sys.path.append("..")

import os
print(os.listdir("../src/agents"))
