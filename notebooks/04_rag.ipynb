# %%
import sys
sys.path.append("..")

from src.rag.embedding_model import OllamaEmbeddingClient

embedder = OllamaEmbeddingClient()

text = "Saving money helps build financial stability."

vector = embedder.embed(text)

print("Vector length:", len(vector))
print("First 5 values:", vector[:5])
# Out:
# Vector length: 768
# First 5 values: [0.6977924704551697, 1.6218619346618652, -3.9190170764923096, 0.3744732737541199, 1.3799118995666504]
